# %%
import sys
sys.path.append('../')

import ACTLiterature as actl
import numpy as np
from matplotlib import pyplot as plt

# Set the redshift of interest here.
redshifts = [0.25, 0.75, 1.25, 1.75, 2.25, 2.75, 3.5]

# %%
for redshift in redshifts:
    plt.figure()

    EddData = actl.EddingtonDistributionData(redshift, datapath="../Data/")
    #plt.plot(EddData.Geo.x, EddData.Geo.y, label = "Geo")

    plt.fill_between(EddData.Geo.x, EddData.Geo.yu, EddData.Geo.yd, alpha=0.4, label = "Geo16, z={}".format(EddData.Geo.z) )

    #plt.plot(EddData.Geo.x, EddData.Geo.yu)
    #plt.plot(EddData.Geo.x, EddData.Geo.yd)

    print('yd', EddData.Geo.yd, print(type(EddData.Geo.yd)))
    
    plt.show()
# Out:
# Warning - we have requested redshift 0.25 - Selecting file Aird2018z0.1.csv as it is closest
# <class 'numpy.ndarray'>
# yd [-9.35338753 -8.97807889 -8.60277025 -8.22746161 -7.85215297 -7.47684432
#  -7.10153568 -6.72622704 -6.3509184  -5.97560976 -5.60030111 -5.22499247
#  -4.73546639 -3.43215541 -2.7801255  -2.44118677 -2.33453332 -2.22787986
#  -2.1212264  -2.00898701 -1.89216663 -1.77534625 -1.65649443 -1.53643124
#  -1.44775587 -1.4940268  -1.54029773 -1.58656866 -1.63283959 -1.68480043
#  -1.73692663 -1.78905283 -1.84117903 -1.87452672 -1.90196355 -1.92940037
#  -1.95683719 -1.98427402 -2.01171084 -2.03914766 -2.06658449 -2.09947132
#  -2.1340797  -2.16868808 -2.20329646 -2.23790484 -2.27251322 -2.3071216
#  -2.34172997 -2.37633835 -2.41094673 -2.47698717 -2.54677596 -2.61656476
#  -2.68635356 -2.74906873 -2.80874678 -2.86842483 -2.92810289 -2.98778094
#  -3.04745899 -3.10592526 -3.15805146 -3.21017766 -3.26230386 -3.31443006
# ...
